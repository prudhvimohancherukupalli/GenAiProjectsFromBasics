# %%
from lanchain_community.document_loaders import TextLoader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from lanchain_community.document_loaders import TextLoader
#
# ModuleNotFoundError: No module named 'lanchain_community'

# %%
print("Hello world")
# Out:
# Running cells with '.conda (Python 3.11.13)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n .conda ipykernel --update-deps --force-reinstall'
